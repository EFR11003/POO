# %% [markdown]
# ## Examen
#
# * Es necesario seguir los lineamientos ya preestablecidos.
#
# * Habrá cero tolerancia al plagio.
#
# * Sólo podrás hacer uso de las libretas que tengas, no se permite el uso de ChatGPT.
#
# * Todas las soluciones deben presentarse de manera lógica. Se penalizará la ausencia de argumentos y de documentación.

# %% [markdown]
# **Ejercicio 1:**
#
# ¿Qué es una clase y por qué es útil? \\
# Define una clase con un ejemplo, dando todas sus características.
#
# Las clases son objetos a las cuales se les asignan atributos. Estas tienen funciones precargadas como por ejemplo pandas es un modulo que tiene dentro clases que puedes reutilizar. De la misma forma tu puedes crear tus clases y reutilizarlas después. Existen las clases madre, las clases heredadas que son subclases de la madre, también existen las clases con y sin polimorfismos.
# Ejemplo de clase heredada, anterioremente se habia escrito la clase madre llamada animal:
#
# class Cat(Animal):
#
#     def __init__(self): #Inicializador
#         Animal.__init__(self) #INICIALIZA LA CLASE MAESTRA DENTRO DE LA SUBORDINADA
#         print("Cat class creada")
#
#     def guess_who(self):
#         print("Soy un gatito")
#
#     def meow(self):
#         print("MEOWW!")
#
# ---

# %% [markdown]
# **Ejercicio 2:**
#
# En Python, un **constructor** es un método especial que se llama automáticamente cuando se crea un objeto. Se utiliza para inicializar los atributos del objeto y realizar cualquier tarea de configuración necesaria antes de su uso. \\
#
# Para este ejercicio contesta las siguientes preguntas:
#
#
# 1.   ¿Cuál es la sintaxis para definir un constructor dentro de una clase?
# 2.   Considera el siguiente código: \\
#
# ![constructor.png](data:image/png;base64,...)
#
# \\
# La clase 'Human' tiene un constructor que toma dos parametros, ¿cuáles son?

# %% [markdown]
# La sintaxis correcta despues de escribir class y el nombre de la clase es
# Una sangria previa a la definición con un tab
# Despues del tab se pone def espacio dos guiones bajos init dos guiones bajos y entre parentesis self con comas entre los argumentos, se cierra el parentesis y se ponen dos puntos
# Ejemplo
#   def __init__(self):
#     print("Ya se inicializó la clase")

# %% [markdown]
# Los parametros de la clase Human son legs y arms que estan igualados a 2

# %% [markdown]
# 3. Crea dos atributos (definiciones y polimorfismos) asociados a la clase 'Human´.
#
# ---

# %%
class Human:
  def __init__(self):
    self.legs=2
    self.arms=2
  def arms(self):
    print("El humano tiene dos brazos")
  def legs(self):
    print("EL humano tiene dos piernas")

# %% [markdown]
# **Ejercicio 3:**
#
# Indica si las siguientes afirmaciones son verdaderas o falsas:
#
#
#
# *   El primer parámetro del método '__ init() __' es siempre 'self' , que se refiere a la instancia de la clase que se está creando. Se pasa automáticamente al constructor cuando se instancia el objeto. **Verdadero** self es una convención, pero puedes darle cualquier nombre válido en Python, aunque es una práctica común usar self.
# *   Después de 'self', puedes definir cualquier otro parámetro necesario para inicializar los atributos del objeto.**Verdadero** Estos parámetros se utilizan para configurar los atributos de la clase.
# *   Cuando añades la función '__ init ()  __' , la clase heredada ya no hereda la función ' __ init () __ ' de la clase madre.**Falso** Cuando añades la función init , la clase heredada no anula la función init de la clase madre a menos que declares una función init en la subclase.
# *   En la programación orientada a objetos, las clases pueden heredar atributos y métodos de otras clases.**Verdadero**. Existen las clases heredadas que como su nombre lo dice son subclases que importan las funciones de la clase madre.
# *  Cuando hablamos de polimorfismos en Python, diferentes clases pueden ser tratadas como instancias de la misma superclase, independientemente de cómo implementen el mismo método.**Verdadero** lo que permite que se comporten de manera diferente cuando se implementa el mismo método a través de una referencia común a la superclase.
#
# ---

# %% [markdown]
# **Ejercicio 4:** A partir de un diccionario, crea un DataFrame (que llamarás **precios_muestra**) que consista de dos columnas y que tenga 12 valores **flotantes** que eligirás de manera aleatoria en el intervalo (8,13). Etiqueta del 1 al 12 y llama a la columna de etiquetas Mes.
#
# 1.- Construye una función que calcule los rendimientos simples de cada columna.
#
# 2.- Las desviaciones estadísticas de los rendimientos ayudan a calcular la volatilidad del portafolio:
# $$\text{desviaciones}=(\text{rendimientos}-\text{media}(\text{rendimientos}))^2.$$
# Crea una función que calcule la media de las desviaciones y luego la volatilidad de tu portafolio (raíz cuadrada de la media de las desviaciones).
#
# 3.- Anualizamos la volatilidad escalándola (multiplicándola) por la raíz cuadrada del número de períodos por observación.
#
# Por lo tanto, para anualizar la volatilidad de una serie mensual, la multiplicamos por la raíz cuadrada de 12. Muestra la serie de la volatilidad anualizada.
#
# 4.- Realiza una gráfica de barras para los rendimientos y una gráfica en líneas para los precios.
#
# 5.- Calcula los rendimientos compuestos para cada columna y después anualiza los rendimientos.
#
# ---

# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
Diccionario = {"Mes": list(range(1, 13)),
        "Precio": [random.uniform(8, 13) for _ in range(12)]}
precios_muestra = pd.DataFrame(Diccionario)
precios_muestra
# Out:
#     Mes     Precio
# 0     1   8.268632
# 1     2  11.514450
# 2     3   8.105386
# 3     4   8.706261
# 4     5  12.177587
# 5     6  12.527026
# 6     7  12.942341
# 7     8  12.660111
# 8     9   8.703572
# 9    10  11.364716
# 10   11   8.359726
# 11   12  10.274065

# %%
def rendimientos_simples(df):
    df["Rendimiento"] = df["Precio"].pct_change()
    return df

precios_muestra = rendimientos_simples(precios_muestra)

# %%
rendimientos_simples(precios_muestra)
# Out:
#     Mes     Precio  Rendimiento
# 0     1   8.268632          NaN
# 1     2  11.514450     0.392546
# 2     3   8.105386    -0.296068
# 3     4   8.706261     0.074133
# 4     5  12.177587     0.398716
# 5     6  12.527026     0.028695
# 6     7  12.942341     0.033154
# 7     8  12.660111    -0.021807
# 8     9   8.703572    -0.312520
# 9    10  11.364716     0.305753
# 10   11   8.359726    -0.264414
# 11   12  10.274065     0.228995

# %%
rendimientos_simples(precios_muestra)["Rendimiento"].std()
# Out:
# 0.26322599128519863

# %%
rendimientos_simples(precios_muestra)["Rendimiento"].std()**12
# Out:
# 1.1064842552519553e-07

# %%
plt.bar(precios_muestra["Mes"], precios_muestra["Rendimiento"])
# Out:
# <BarContainer object of 12 artists>

# %%
plt.plot(precios_muestra["Mes"], precios_muestra["Precio"])

# %%
def rendimientos_compuestos(df):
    df["Rendimiento_Compuesto"] = (1 + df["Rendimiento"]).cumprod() - 1
    return df

precios_muestra = rendimientos_compuestos(precios_muestra)

# %%
rendimientos_compuestos(precios_muestra)
# Out:
#     Mes     Precio  Rendimiento  Rendimiento_Compuesto
# 0     1   8.268632          NaN                    NaN
# 1     2  11.514450     0.392546               0.392546
# 2     3   8.105386    -0.296068              -0.019743
# 3     4   8.706261     0.074133               0.052926
# 4     5  12.177587     0.398716               0.472745
# 5     6  12.527026     0.028695               0.515006
# 6     7  12.942341     0.033154               0.565234
# 7     8  12.660111    -0.021807               0.531101
# 8     9   8.703572    -0.312520               0.052601
# 9    10  11.364716     0.305753               0.374437
# 10   11   8.359726    -0.264414               0.011017
# 11   12  10.274065     0.228995               0.242535

# %%
rendimientos_anuales=rendimientos_compuestos(precios_muestra)["Rendimiento_Compuesto"].mean()**252
rendimientos_anuales
# Out:
# 3.452986131813913e-136

# %% [markdown]
# **Ejercicio 5:** Carga dos tickers y realiza los pasos del ejercicio anterior usando los tickers que elijas. Recuerda tomar en cuenta la ventana de tiempo que manejarás. Realiza un análisis estadístico (estadística descriptiva, histogramas y gráficas de series de tiempo).

# %%
import yfinance as yf

# %%
tickers= (["AAPL", "MSFT"])
fechainicial="2020-01-01"
fechafinal="2023-01-01"

# %%
datos= yf.download(tickers, fechainicial, fechafinal) ["Close"]
datos
# Out:
# [*********************100%%**********************]  2 of 2 completed
#                   AAPL        MSFT
# Date
# 2020-01-02   75.087502  160.619995
# 2020-01-03   74.357498  158.619995
# 2020-01-06   74.949997  159.029999
# 2020-01-07   74.597504  157.580002
# 2020-01-08   75.797501  160.089996
# ...                ...         ...
# 2022-12-23  131.860001  238.729996
# 2022-12-27  130.029999  236.960007
# 2022-12-28  126.040001  234.529999
# 2022-12-29  129.610001  241.009995
# 2022-12-30  129.929993  239.820007
#
# [756 rows x 2 columns]

# %%
datos.describe()
# Out:
#              AAPL        MSFT
# count  756.000000  756.000000
# mean   130.311812  245.860939
# std     30.566496   47.582265
# min     56.092499  135.419998
# 25%    115.739374  212.474998
# 50%    135.379997  245.144997
# 75%    150.704998  283.737495
# max    182.009995  343.109985

# %%
returns=datos.pct_change()
returns
# Out:
#                 AAPL      MSFT
# Date
# 2020-01-02       NaN       NaN
# 2020-01-03 -0.009722 -0.012452
# 2020-01-06  0.007968  0.002585
# 2020-01-07 -0.004703 -0.009118
# 2020-01-08  0.016086  0.015928
# ...              ...       ...
# 2022-12-23 -0.002798  0.002267
# 2022-12-27 -0.013878 -0.007414
# 2022-12-28 -0.030685 -0.010255
# 2022-12-29  0.028324  0.027630
# 2022-12-30  0.002469 -0.004938
#
# [756 rows x 2 columns]

# %%
returns.std()
# Out:
# AAPL    0.023268
# MSFT    0.021904
# dtype: float64

# %%
returns.var()
# Out:
# AAPL    0.000541
# MSFT    0.000480
# dtype: float64

# %%
returns.mean()
# Out:
# AAPL    0.000997
# MSFT    0.000771
# dtype: float64

# %%
(1+returns.mean())**252-1
# Out:
# AAPL    0.285364
# MSFT    0.214352
# dtype: float64

# %%
returns.hist()
# Out:
# array([[<Axes: title={'center': 'AAPL'}>,
#         <Axes: title={'center': 'MSFT'}>]], dtype=object)

# %%
returns.plot()
# Out:
# <Axes: xlabel='Date'>
