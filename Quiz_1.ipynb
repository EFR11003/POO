# %% [markdown]
# #Quiz
# 1.- Crea un diccionario que contenga 3 llaves que sean de tipo string y cuyos valores sean una lista que contenga 5 valores (3 numéricos y 2 flotantes).
#
# 2.- A partir del diccionario anterior, muestra a sus ítems. ¿Qué tipo de objeto se obtiene?
#
# 3.- Crea un panel de datos usando tu diccionario. Realiza tres segregaciones distintas.
#
# 4.- Realiza un breve análisis descriptivo de tu panel de datos. Explica los valores que obtienes.
#
# 5.- Realiza dos filtros de búsqueda sobre tu panel de datos.

# %%
Ejercicio_1={"Eduardo":[9,8,7,8.5,9.6],
             "Pepe":[8,7,3,5.5,6.6],
             "Juan":[7,6,5,5.4,6.3]}

# %%
Ejercicio_1
# Out:
# {'Eduardo': [9, 8, 7, 8.5, 9.6],
#  'Pepe': [8, 7, 3, 5.5, 6.6],
#  'Juan': [7, 6, 5, 5.4, 6.3]}

# %%
#Ejercicio 2
type(Ejercicio_1)
# Out:
# dict

# %%
import pandas as pd

# %%
#Ejercicio 3
df=pd.DataFrame(Ejercicio_1)

# %%
df
# Out:
#    Eduardo  Pepe  Juan
# 0      9.0   8.0   7.0
# 1      8.0   7.0   6.0
# 2      7.0   3.0   5.0
# 3      8.5   5.5   5.4
# 4      9.6   6.6   6.3

# %%
df.iloc[1:2]
# Out:
#    Eduardo  Pepe  Juan
# 1      8.0   7.0   6.0

# %%
df.drop(columns="Pepe")
# Out:
#    Eduardo  Juan
# 0      9.0   7.0
# 1      8.0   6.0
# 2      7.0   5.0
# 3      8.5   5.4
# 4      9.6   6.3

# %%
df.iloc[:,[1,2]]
# Out:
#    Pepe  Juan
# 0   8.0   7.0
# 1   7.0   6.0
# 2   3.0   5.0
# 3   5.5   5.4
# 4   6.6   6.3

# %%
#Ejercicio 4
df.describe()
# Out:
#         Eduardo      Pepe      Juan
# count  5.000000  5.000000  5.000000
# mean   8.420000  6.020000  5.940000
# std    0.990959  1.911021  0.779744
# min    7.000000  3.000000  5.000000
# 25%    8.000000  5.500000  5.400000
# 50%    8.500000  6.600000  6.000000
# 75%    9.000000  7.000000  6.300000
# max    9.600000  8.000000  7.000000

# %% [markdown]
# Explicación=El promedio de calificaciones de Eduardo es más grande que Pepe y Juan, Juan tiene la menor variacion de calificaciónes, por lo que su desviación estándar es menor. La persona con  la calificación más baja fue Pepe con 3, y la calificación más alta la tuvo Eduardo con 9.6

# %%
#Ejercicio 5
df.mean()
# Out:
# Eduardo    8.42
# Pepe       6.02
# Juan       5.94
# dtype: float64

# %%
df.max()
# Out:
# Eduardo    9.6
# Pepe       8.0
# Juan       7.0
# dtype: float64
