# %%
import pandas as pd

d = pd.read_csv("ETF prices.csv")
d
# Out:
#         fund_symbol  price_date   open   high    low  close  adj_close  volume
# 0               AAA  2020-09-09  25.10  25.12  25.07  25.07      24.85   17300
# 1               AAA  2020-09-10  25.06  25.07  25.05  25.07      24.85   23500
# 2               AAA  2020-09-11  25.04  25.05  25.02  25.03      24.81   33400
# 3               AAA  2020-09-14  25.01  25.06  25.01  25.02      24.80   13100
# 4               AAA  2020-09-15  25.02  25.03  25.01  25.01      24.79   12100
# ...             ...         ...    ...    ...    ...    ...        ...     ...
# 3866025         ZSL  2021-11-23  26.81  27.21  26.30  26.35      26.35  190900
# 3866026         ZSL  2021-11-24  26.79  26.96  26.57  26.69      26.69  109000
# 3866027         ZSL  2021-11-26  26.67  28.14  26.67  27.72      27.72  205500
# 3866028         ZSL  2021-11-29  27.89  28.56  27.80  28.27      28.27  411900
# 3866029         ZSL  2021-11-30  28.15  28.73  25.91  28.49      28.49  219400
#
# ...

# %%
d = d.iloc[0:100]
d
# Out:
#    fund_symbol  price_date   open  close  adj_close  volume
# 0          AAA  2020-09-09  25.10  25.07      24.85   17300
# 1          AAA  2020-09-10  25.06  25.07      24.85   23500
# 2          AAA  2020-09-11  25.04  25.03      24.81   33400
# 3          AAA  2020-09-14  25.01  25.02      24.80   13100
# 4          AAA  2020-09-15  25.02  25.01      24.79   12100
# ..         ...         ...    ...    ...        ...     ...
# 95         AAA  2021-01-26  25.16  25.17      25.02     500
# 96         AAA  2021-01-27  25.14  25.15      25.01     500
# 97         AAA  2021-01-28  25.15  25.15      25.01     200
# 98         AAA  2021-01-29  25.16  25.15      25.00    3100
# 99         AAA  2021-02-01  25.14  25.13      25.01    1300
#
# [100 rows x 6 columns]

# %%
d.iloc[:,[1,2,5]]
# Out:
#     price_date   open  volume
# 0   2020-09-09  25.10   17300
# 1   2020-09-10  25.06   23500
# 2   2020-09-11  25.04   33400
# 3   2020-09-14  25.01   13100
# 4   2020-09-15  25.02   12100
# ..         ...    ...     ...
# 95  2021-01-26  25.16     500
# 96  2021-01-27  25.14     500
# 97  2021-01-28  25.15     200
# 98  2021-01-29  25.16    3100
# 99  2021-02-01  25.14    1300
#
# [100 rows x 3 columns]

# %%
d["close"].value_counts() #Tabla de frecuencias
# Out:
# 25.07    10
# 24.95     7
# 24.91     7
# 25.15     6
# 25.08     6
# 24.98     6
# 25.06     6
# 25.05     5
# 25.03     5
# 24.90     4
# 25.09     4
# 25.04     4
# 24.89     4
# 24.92     4
# 24.93     3
# 24.94     3
# 25.01     3
# 25.10     2
# 25.16     2
# 24.87     1
# 25.00     1
# 24.96     1
# 24.99     1
# 24.97     1
# 25.12     1
# 25.02     1
# 25.17     1
# 25.13     1
# Name: close, dtype: int64

# %%
d.describe() #Te da valores de estadistica descriptiva
# Out:
#              open       close   adj_close         volume
# count  100.000000  100.000000  100.000000     100.000000
# mean    25.015900   25.014900   24.835500    5404.000000
# std      0.081353    0.080735    0.104933   12979.470348
# min     24.870000   24.870000   24.690000       0.000000
# 25%     24.940000   24.940000   24.740000     500.000000
# 50%     25.030000   25.030000   24.850000    1800.000000
# 75%     25.070000   25.070000   24.930000    4500.000000
# max     25.160000   25.170000   25.020000  115400.000000

# %%
d.mean(axis=0
    )
# Out:
# C:\Users\edyfa\AppData\Local\Temp\ipykernel_6992\2294291198.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.mean(axis=0
# open           25.0159
# close          25.0149
# adj_close      24.8355
# volume       5404.0000
# dtype: float64
